# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %%
df = pd.read_csv('../../../globalterrorismdb_0616dist.csv')
# Out:
# /Users/avinashtamby/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (4,61,62,66,116,117,123) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.region_txt.value_counts().plot(kind='bar')
plt.title('Number of Terror Attacks By Region 1970 - 2015')
plt.savefig('terrorbyregion.png')

# %%
df.attacktype1_txt.value_counts().plot(kind='bar')
plt.title('Types of Terror Attacks 1970-2015')

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)    # The big subplot
ax1 = fig.add_subplot(3,4,1) #numbers are: nrows, ncols, place counting through rows then cols
ax2 = fig.add_subplot(3,4,2)
ax3 = fig.add_subplot(3,4,3)
ax4 = fig.add_subplot(3,4,4)

ax5 = fig.add_subplot(3,4,5)
ax6 = fig.add_subplot(3,4,6)
ax7 = fig.add_subplot(3,4,7)
ax8 = fig.add_subplot(3,4,8)

ax9 = fig.add_subplot(3,4,9)
ax10 = fig.add_subplot(3,4,10)
ax11 = fig.add_subplot(3,4,11)
ax12 = fig.add_subplot(3,4,12)

# Turn off axis lines and ticks of the big subplot
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')

df.attacktype1_txt[df.region_txt == df.region_txt.unique()[0]].value_counts().plot(kind='bar', title = df.region_txt.unique()[0], ax=ax1)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[1]].value_counts().plot(kind='bar', title = df.region_txt.unique()[1], ax=ax2)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[2]].value_counts().plot(kind='bar', title = df.region_txt.unique()[2], ax=ax3)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[3]].value_counts().plot(kind='bar', title = df.region_txt.unique()[3], ax=ax4)

df.attacktype1_txt[df.region_txt == df.region_txt.unique()[4]].value_counts().plot(kind='bar', title = df.region_txt.unique()[4], ax=ax5)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[5]].value_counts().plot(kind='bar', title = df.region_txt.unique()[5], ax=ax6)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[6]].value_counts().plot(kind='bar', title = df.region_txt.unique()[6], ax=ax7)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[7]].value_counts().plot(kind='bar', title = df.region_txt.unique()[7], ax=ax8)

df.attacktype1_txt[df.region_txt == df.region_txt.unique()[8]].value_counts().plot(kind='bar', title = df.region_txt.unique()[8], ax=ax9)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[9]].value_counts().plot(kind='bar', title = df.region_txt.unique()[9], ax=ax10)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[10]].value_counts().plot(kind='bar', title = df.region_txt.unique()[10], ax=ax11)
df.attacktype1_txt[df.region_txt == df.region_txt.unique()[11]].value_counts().plot(kind='bar', title = df.region_txt.unique()[11], ax=ax12)

plt.tight_layout(rect=[0,0,1,2])
ax.set_title('Types of Terror Attacks By Region')
plt.savefig('TerrorAttacksByRegion.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111)    # The big subplot
ax1 = fig.add_subplot(3,4,1) #numbers are: nrows, ncols, place counting through rows then cols
ax2 = fig.add_subplot(3,4,2)
ax3 = fig.add_subplot(3,4,3)
ax4 = fig.add_subplot(3,4,4)

ax5 = fig.add_subplot(3,4,5)
ax6 = fig.add_subplot(3,4,6)
ax7 = fig.add_subplot(3,4,7)
ax8 = fig.add_subplot(3,4,8)

ax9 = fig.add_subplot(3,4,9)
ax10 = fig.add_subplot(3,4,10)
ax11 = fig.add_subplot(3,4,11)
ax12 = fig.add_subplot(3,4,12)

# Turn off axis lines and ticks of the big subplot
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')

df[(df.region_txt == df.region_txt.unique()[0]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[0], ax=ax1)
df[(df.region_txt == df.region_txt.unique()[1]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[1], ax=ax2)
df[(df.region_txt == df.region_txt.unique()[2]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[2], ax=ax3)
df[(df.region_txt == df.region_txt.unique()[3]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[3], ax=ax4)

df[(df.region_txt == df.region_txt.unique()[4]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[4], ax=ax5)
df[(df.region_txt == df.region_txt.unique()[5]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[5], ax=ax6)
df[(df.region_txt == df.region_txt.unique()[6]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[6], ax=ax7)
df[(df.region_txt == df.region_txt.unique()[7]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[7], ax=ax8)

df[(df.region_txt == df.region_txt.unique()[8]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[8], ax=ax9)
df[(df.region_txt == df.region_txt.unique()[9]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[9], ax=ax10)
df[(df.region_txt == df.region_txt.unique()[10]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[10], ax=ax11)
df[(df.region_txt == df.region_txt.unique()[11]) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.plot(kind='hist', bins=46, title=df.region_txt.unique()[11], ax=ax12)

plt.tight_layout(rect=[0,0,1,1])
ax.set_title('Bombings/Explosions by Region')
plt.savefig('BombByRegion.png', bbox_inches='tight')

# %%
df.iyear.plot(kind='hist', bins=46, title='Total Terrorist Attacks by Year')
plt.xlabel('Year')
plt.ylabel('Number of Terrorist Attacks')
plt.savefig('Attacks.png', bbox_inches='tight')

# %%
df.groupby('iyear').nkill.sum().plot(kind='bar', title='Number of People Killed By Terror Attacks By Year', fontsize=9)

# %%
df.groupby('iyear').nkill.sum().plot(kind='bar', title='Number of People Killed By Terror Attacks By Year', fontsize=9)
plt.ylabel('Number of Deaths')
plt.savefig('Death.png', bbox_inches='tight')

# %%
df[(df.country_txt == 'United States')].groupby('iyear').nkillus.sum().mean()
# Out:
# 74.93333333333334

# %%
df[(df.country_txt == 'United States')].groupby('iyear').nkillus.sum().plot(
    kind='bar', title='American Citizens killed by terror attacks in the US, Including 9/11', fontsize=9)
plt.savefig('USterror911.png', bbox_inches='tight')

# %%
df[(df.country_txt == 'United States') & (~df.addnotes.str.contains('This attack was one of four related incidents',
                                                                    na=False)) & 
   (df)].groupby('iyear').nkillus.sum().plot(
    kind='bar', title='American Citizens killed by terror attacks in the US, Excluding 9/11', fontsize=9)
plt.savefig('USterror.png', bbox_inches='tight')

# %%
df[df.attacktype1_txt == 'Hijacking'].iyear.plot(kind='hist', bins=46, title='Total Terrorist Attacks by Year')
plt.xlabel('Year')
plt.ylabel('Number of Terrorist Attacks')

# %%
# 4954 attacks in 1993
print df[df.attacktype1_txt == 'Bombing/Explosion'].iyear.value_counts().mean() / df.iyear.value_counts().mean()

print ''

print df[(df.iyear == 1990) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1990].iyear.value_counts().mean()
print df[(df.iyear == 1991) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1991].iyear.value_counts().mean()
print df[(df.iyear == 1992) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1992].iyear.value_counts().mean()

print ''

print df[(df.iyear == 1994) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1994].iyear.value_counts().mean()
print df[(df.iyear == 1995) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1995].iyear.value_counts().mean()
print df[(df.iyear == 1996) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1996].iyear.value_counts().mean()

print ''

print 4954 * (df[(df.iyear == 1992) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1992].iyear.value_counts().mean() + df[(df.iyear == 1994) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1994].iyear.value_counts().mean()) / 2
# Out:
# 0.484544433955
#
# 0.445330589143
# 0.424514200299
# 0.342598068204
#
# 0.333429728167
# 0.256734826355
# 0.398232984293
#
# 1674.52085161

# %%
a = df[(df.iyear == 1992) & (df.attacktype1_txt == 'Bombing/Explosion')].groupby('iyear').nkill.sum().values[0] / df[(df.iyear == 1992)].groupby('iyear').nkill.sum().values[0]
print a
b = df[(df.iyear == 1994) & (df.attacktype1_txt == 'Bombing/Explosion')].groupby('iyear').nkill.sum().values[0] / df[(df.iyear == 1994)].groupby('iyear').nkill.sum().values[0]
print b

10162*(a+b)/2
# Out:
# 0.169214982042
# 0.16330776232
# 1689.5480641016309

# %%
print (df[(df.iyear == 1992) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1992].iyear.value_counts().mean() + df[(df.iyear == 1994) & (df.attacktype1_txt == 'Bombing/Explosion')].iyear.value_counts().mean() / df[df.iyear == 1994].iyear.value_counts().mean()) / 2

print (df[(df.iyear == 1992) & (df.attacktype1_txt == 'Bombing/Explosion')].groupby('iyear').nkill.sum()# / df[df.iyear == 1992].groupby('iyear').nkill.sum().values) 
#+ (df[(df.iyear == 1994) & (df.attacktype1_txt == 'Bombing/Explosion')].groupby('iyear').nkill.sum() / df[df.iyear == 1994].groupby('iyear').nkill.sum())
# Out:
#   File "<ipython-input-113-32399750b37b>", line 4
#     #+ (df[(df.iyear == 1994) & (df.attacktype1_txt == 'Bombing/Explosion')].groupby('iyear').nkill.sum() / df[df.iyear == 1994].groupby('iyear').nkill.sum())
#                                                                                                                                                               ^
# SyntaxError: invalid syntax

# %%
df[(df.iyear == 1992) & (df.attacktype1_txt == 'Bombing/Explosion')].country_txt.value_counts()
# Out:
# Colombia                    307
# Peru                        201
# United Kingdom              119
# Turkey                      104
# France                       91
# Chile                        89
# Philippines                  62
# India                        57
# Lebanon                      48
# Spain                        40
# Algeria                      33
# South Africa                 32
# Argentina                    30
# Bolivia                      29
# Pakistan                     28
# Sri Lanka                    27
# Guatemala                    27
# Cambodia                     21
# Panama                       21
# Georgia                      18
# Greece                       17
# Togo                         17
# Italy                        15
# Japan                        15
# Yemen                        14
# Afghanistan                  13
# Ecuador                      12
# Israel                       12
# West Bank and Gaza Strip     12
# Thailand                     11
#                            ...
# Netherlands                   2
# Bulgaria                      2
# Austria                       2
# Sudan                         2
# Kuwait                        2
# China                         2
# Tajikistan                    2
# Uganda                        1
# Nigeria                       1
# Romania                       1
# Suriname                      1
# Mexico                        1
# Ireland                       1
# Western Sahara                1
# Latvia                        1
# Belgium                       1
# Finland                       1
# Poland                        1
# Sierra Leone                  1
# Denmark                       1
# Jordan                        1
# Ukraine                       1
# Switzerland                   1
# Kazakhstan                    1
# Estonia                       1
# Zimbabwe                      1
# Djibouti                      1
# Mozambique                    1
# Niger                         1
# Canada                        1
# Name: country_txt, dtype: int64

# %%
df[(df.iyear == 1994) & (df.attacktype1_txt == 'Bombing/Explosion')].country_txt.value_counts()
# Out:
# Turkey                      141
# Colombia                     91
# United Kingdom               90
# France                       67
# Peru                         55
# Bangladesh                   51
# Guatemala                    51
# Lebanon                      48
# India                        42
# Spain                        33
# South Africa                 32
# Greece                       29
# Iran                         28
# West Bank and Gaza Strip     22
# Russia                       22
# Pakistan                     20
# Philippines                  19
# Sri Lanka                    18
# Thailand                     16
# Algeria                      13
# Israel                       13
# Chile                        12
# Iraq                         11
# Tajikistan                   11
# Egypt                        10
# Argentina                     9
# Mexico                        9
# Cambodia                      9
# Georgia                       8
# United States                 8
#                            ...
# Togo                          3
# Ukraine                       3
# Luxembourg                    3
# Hungary                       2
# Panama                        2
# Ecuador                       2
# Canada                        2
# Zaire                         2
# Honduras                      2
# Kenya                         1
# Taiwan                        1
# Norway                        1
# Djibouti                      1
# Namibia                       1
# Chad                          1
# Kuwait                        1
# Indonesia                     1
# Republic of the Congo         1
# Germany                       1
# Bulgaria                      1
# Cameroon                      1
# Yemen                         1
# Vietnam                       1
# Netherlands                   1
# Latvia                        1
# Morocco                       1
# Moldova                       1
# Macedonia                     1
# Finland                       1
# Albania                       1
# Name: country_txt, dtype: int64

# %%
df.attacktype1_txt.value_counts()
# Out:
# Bombing/Explosion                      75963
# Armed Assault                          37554
# Assassination                          17582
# Hostage Taking (Kidnapping)             9115
# Facility/Infrastructure Attack          8849
# Unknown                                 5490
# Hostage Taking (Barricade Incident)      835
# Unarmed Assault                          828
# Hijacking                                556
# Name: attacktype1_txt, dtype: int64
